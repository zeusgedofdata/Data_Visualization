# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# # Cities Breakdown

# %%
cities_18_dis =  pd.read_csv( r"C:/Users/zeusg/OneDrive/Documents/Github/data_vis/data/CDP/Cities/Cities Disclosing/2018_Cities_Disclosing_to_CDP.csv")

# %%
cities_18_dis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 13 columns):
# Year Reported to CDP    641 non-null int64
# Account Number          641 non-null int64
# Organization            641 non-null object
# City                    641 non-null object
# Country                 641 non-null object
# CDP Region              641 non-null object
# Reporting Authority     641 non-null object
# Access                  641 non-null object
# First Time Discloser    641 non-null object
# Population              586 non-null float64
# Population Year         641 non-null int64
# City Location           641 non-null object
# Last update             641 non-null object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 65.2+ KB

# %%
# Simplify removing duplicate columns
cities_18_dis = cities_18_dis[['Year Reported to CDP', 'Account Number', 'City', 'Country', 'CDP Region', 'Access', 'Population', 'Population Year', 'City Location']]
#Rename columns
cities_18_dis = cities_18_dis.rename(columns={'Year Reported to CDP': 'Year', 'Account Number': 'Account','CDP Region':'Region','City Location':'Location'})

# %%
cities_18_dis.head()
# Out:
#    Year  Account                        City                   Country  \
# 0  2018    58671                   Helsingør                   Denmark
# 1  2018    59167                 Providencia                     Chile
# 2  2018    50553                      Fresno  United States of America
# 3  2018   826407                   Mirandela                  Portugal
# 4  2018    60375  Archipiélago de San Andrés                  Colombia
#
#           Region  Access  Population  Population Year  \
# 0         Europe  public     62686.0             2017
# 1  Latin America  public    126487.0             2012
# 2  North America  public    527438.0             2017
# 3         Europe  public     11852.0             2011
# 4  Latin America  public    120000.0             2017
#
#                     Location
# 0    POINT (12.5921 56.0308)
# 1  POINT (-70.6092 -33.4313)
# 2   POINT (-119.773 36.7468)
# 3      POINT (-7.1753 41.51)
# 4   POINT (-81.6976 12.5794)

# %% [markdown]
# ## Cities Responses

# %%
cities_18_res =  pd.read_csv( r"C:/Users/zeusg/OneDrive/Documents/Github/data_vis/data/CDP/Cities/Cities Responses/2018_Full_Cities_Dataset.csv")

# %%
cities_18_res.head()
# Out:
#      Questionnaire  Year Reported to CDP  Account Number  \
# 0  CDP Cities 2018                  2018            3203
# 1  CDP Cities 2018                  2018           50555
# 2  CDP Cities 2018                  2018           50392
# 3  CDP Cities 2018                  2018           36522
# 4  CDP Cities 2018                  2018           35873
#
#                Organization                   Country     CDP Region  \
# 0           City of Chicago  United States of America  North America
# 1          City of Hamilton                    Canada  North America
# 2     Prefeitura de Vitória                    Brazil  Latin America
# 3        Comune di Verbania                     Italy         Europe
# 4  Municipality of Medellín                  Colombia  Latin America
#
#                    Parent Section                                  Section  \
# 0                           Water                               Wastewater
# ...

# %%
_ = cities_18_res.loc[cities_18_res['Organization'] == 'New York City']

# %%
_
# Out:
#           Questionnaire  Year Reported to CDP  Account Number   Organization  \
# 480     CDP Cities 2018                  2018            3417  New York City
# 529     CDP Cities 2018                  2018            3417  New York City
# 561     CDP Cities 2018                  2018            3417  New York City
# 623     CDP Cities 2018                  2018            3417  New York City
# 849     CDP Cities 2018                  2018            3417  New York City
# ...                 ...                   ...             ...            ...
# 185859  CDP Cities 2018                  2018            3417  New York City
# 185897  CDP Cities 2018                  2018            3417  New York City
# 186265  CDP Cities 2018                  2018            3417  New York City
# 186631  CDP Cities 2018                  2018            3417  New York City
# 186659  CDP Cities 2018                  2018            3417  New York City
#
# ...
