# %%
import csv
import requests
import pandas as pd
import io
import plotly.express as px

# %%
url = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-12-01/shelters.csv'

response=requests.get(url).content

tornado_df=pd.read_csv(io.StringIO(response.decode('utf-8')))

# %%
tornado_df.head()
# Out:
#    id       occupancy_date                        organization_name  \
# 0   1  2017-01-01T00:00:00                 COSTI Immigrant Services
# 1   2  2017-01-01T00:00:00  Christie Ossington Neighbourhood Centre
# 2   3  2017-01-01T00:00:00  Christie Ossington Neighbourhood Centre
# 3   4  2017-01-01T00:00:00    Christie Refugee Welcome Centre, Inc.
# 4   5  2017-01-01T00:00:00                          City of Toronto
#
#                       shelter_name        shelter_address shelter_city  \
# 0           COSTI Reception Centre  100 Lippincott Street      Toronto
# 1  Christie Ossington Men's Hostel   973 Lansdowne Avenue      Toronto
# 2  Christie Ossington Men's Hostel   973 Lansdowne Avenue      Toronto
# 3  Christie Refugee Welcome Centre     43 Christie Street      Toronto
# 4             Birchmount Residence     1673 Kingston Road      Toronto
#
#   shelter_province shelter_postal_code                    facility_name  \
# 0               ON             M5S 2P1           COSTI Reception Centre
# 1               ON             M6H 3Z5  Christie Ossington Men's Hostel
# 2               ON             M6H 3Z5  Christie Ossington Men's Hostel
# 3               ON             M6G 3B1  Christie Refugee Welcome Centre
# 4               ON                 NaN  Birchmount Res 1673 Kingston Rd
#
#                                         program_name    sector  occupancy  \
# 0                   COSTI Reception Ctr CITY Program     Co-ed         16
# 1         Christie Ossington Extreme Weather Program       Men         13
# 2                    Christie Ossington Men's Hostel       Men         63
# 3  Christie Refugee Welcome Ctr - Settlement and ...  Families         66
# 4                               Birchmount Residence       Men         58
#
#    capacity
# 0      16.0
# 1      17.0
# 2      63.0
# 3      70.0
# 4      60.0

# %%
tornado_df.describe()
# Out:
#                   id      occupancy       capacity
# count  115916.000000  115916.000000  115573.000000
# mean    19325.915887      56.970211      60.528861
# std     11164.582502      83.188821      92.601212
# min         1.000000       0.000000       0.000000
# 25%      9660.000000      13.000000      16.000000
# 50%     19320.000000      37.000000      40.000000
# 75%     28979.250000      69.000000      71.000000
# max     39446.000000     826.000000     902.000000

# %%
tornado_df.isnull().sum()
tornado_df = tornado_df[tornado_df['capacity'].notna()]
tornado_df.isnull().sum()
# Out:
# id                        0
# occupancy_date            0
# organization_name         0
# shelter_name              0
# shelter_address           0
# shelter_city              0
# shelter_province          0
# shelter_postal_code    5494
# facility_name             0
# program_name              0
# sector                    0
# occupancy                 0
# capacity                  0
# dtype: int64

# %%
sector = tornado_df.groupby(by=["occupancy_date","sector"]).sum()

# %%
sector = sector.reset_index()
sector['percent_full'] = sector['occupancy']/sector['capacity'] 
sector.head()
# Out:
#         occupancy_date    sector    id  occupancy  capacity  percent_full
# 0  2017-01-01T00:00:00     Co-ed   742        530     582.0      0.910653
# 1  2017-01-01T00:00:00  Families   501       1030    1150.0      0.895652
# 2  2017-01-01T00:00:00       Men  1635       1595    1706.0      0.934936
# 3  2017-01-01T00:00:00     Women  1318        641     697.0      0.919656
# 4  2017-01-01T00:00:00     Youth  1190        499     518.0      0.963320

# %%
fig = px.line(sector[sector['sector']=='Families'], x="occupancy_date", y = "percent_full", color = "sector")
fig.show()

# %%
sector[sector['sector']!='Men']
# Out:
#            occupancy_date    sector       id  occupancy  capacity  \
# 0     2017-01-01T00:00:00     Co-ed      742        530     582.0
# 1     2017-01-01T00:00:00  Families      501       1030    1150.0
# 3     2017-01-01T00:00:00     Women     1318        641     697.0
# 4     2017-01-01T00:00:00     Youth     1190        499     518.0
# 5     2017-01-02T00:00:00     Co-ed    49522        458     582.0
# ...                   ...       ...      ...        ...       ...
# 5469  2019-12-30T00:00:00     Youth   667965        532     543.0
# 5470  2019-12-31T00:00:00     Co-ed   748381        795     815.0
# 5471  2019-12-31T00:00:00  Families   590476       2675    2932.0
# 5473  2019-12-31T00:00:00     Women  1063721        958     979.0
# 5474  2019-12-31T00:00:00     Youth   669903        536     543.0
#
#       percent_full
# 0         0.910653
# 1         0.895652
# 3         0.919656
# 4         0.963320
# 5         0.786942
# ...            ...
# 5469      0.979742
# 5470      0.975460
# 5471      0.912347
# 5473      0.978550
# 5474      0.987109
#
# [4380 rows x 6 columns]

# %%
sector.dtypes
# Out:
# occupancy_date     object
# sector             object
# id                  int64
# occupancy           int64
# capacity          float64
# percent_full      float64
# dtype: object

# %%
sector['occupancy_date'] = pd.to_datetime(sector['occupancy_date'], format="%Y-%m-%dT%H:%M:%S")
sector.head()
# Out:
#   occupancy_date    sector    id  occupancy  capacity  percent_full
# 0     2017-01-01     Co-ed   742        530     582.0      0.910653
# 1     2017-01-01  Families   501       1030    1150.0      0.895652
# 2     2017-01-01       Men  1635       1595    1706.0      0.934936
# 3     2017-01-01     Women  1318        641     697.0      0.919656
# 4     2017-01-01     Youth  1190        499     518.0      0.963320

# %%
sector.dtypes
# Out:
# occupancy_date    datetime64[ns]
# sector                    object
# id                         int64
# occupancy                  int64
# capacity                 float64
# percent_full             float64
# dtype: object

# %%
sector['occupancy_date'] = sector['occupancy_date'].dt.strftime('%Y - %m ')
sector.head()
# Out:
#   occupancy_date    sector    id  occupancy  capacity  percent_full
# 0     2017 - 01      Co-ed   742        530     582.0      0.910653
# 1     2017 - 01   Families   501       1030    1150.0      0.895652
# 2     2017 - 01        Men  1635       1595    1706.0      0.934936
# 3     2017 - 01      Women  1318        641     697.0      0.919656
# 4     2017 - 01      Youth  1190        499     518.0      0.963320

# %%
sector = sector.groupby(by=["occupancy_date","sector"]).mean()
sector = sector.reset_index()
sector.head()
# Out:
#   occupancy_date    sector             id    occupancy     capacity  \
# 0     2017 - 01      Co-ed  129492.709677   501.225806   590.387097
# 1     2017 - 01   Families  129889.903226  1221.419355  1302.548387
# 2     2017 - 01        Men  291737.096774  1657.225806  1753.516129
# 3     2017 - 01      Women  175032.645161   669.161290   698.967742
# 4     2017 - 01      Youth  137680.032258   499.064516   518.000000
#
#    percent_full
# 0      0.849438
# 1      0.934599
# 2      0.945121
# 3      0.957274
# 4      0.963445

# %%
sector['percent_full'] = sector['occupancy']/sector['capacity'] 
sector.head()
# Out:
#   occupancy_date    sector             id    occupancy     capacity  \
# 0     2017 - 01      Co-ed  129492.709677   501.225806   590.387097
# 1     2017 - 01   Families  129889.903226  1221.419355  1302.548387
# 2     2017 - 01        Men  291737.096774  1657.225806  1753.516129
# 3     2017 - 01      Women  175032.645161   669.161290   698.967742
# 4     2017 - 01      Youth  137680.032258   499.064516   518.000000
#
#    percent_full
# 0      0.848978
# 1      0.937715
# 2      0.945087
# 3      0.957356
# 4      0.963445

# %%
fig = px.line(sector, x="occupancy_date", y = "percent_full", color = "sector")
fig.show()

# %%
fig = px.bar(sector, x="occupancy_date", y = "percent_full", color = "sector", barmode='group')
fig.show()

# %%
fig = px.line(sector, x="occupancy_date", y = "capacity", color = "sector")
fig.show()

# %%
fig = px.line(sector, x="occupancy_date", y = "occupancy", color = "sector")
fig.show()
